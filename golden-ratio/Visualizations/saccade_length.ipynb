# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams['figure.figsize'] = (16, 9)
sns.set(style="white")

# %%
def condition_convert(x):
    return 'GoldenRatio' if x == 1 else 'Compact'

# %%
df = pd.read_csv('../fixation_features.csv', sep=',').dropna().reset_index(drop=True)
df.saccade_length = df.saccade_length / 20
df.condition = df.condition.apply(condition_convert)
df.doc = df.doc.apply(lambda x: x[0])
df.participant = df.participant.apply(lambda x: 'P0'+str(x) if len(str(x))==1 else 'P'+str(x))

# %%
ax = sns.catplot(x="condition", y="saccade_length", 
                data=df, kind="bar");
ax.set(xlabel="Condition", ylabel = "Saccadic Length")

# %%
df.participant
# Out:
# 0       P01
# 1       P01
# 2       P01
# 3       P01
# 4       P01
#        ...
# 8594    P11
# 8595    P11
# 8596    P11
# 8597    P11
# 8598    P11
# Name: participant, Length: 8599, dtype: object

# %%
ax = sns.barplot(x="participant", y="saccade_length", hue="condition", data=df[df.saccade_length<100])

# %%
x = df[df.saccade_length<200]

# %%
x[x.condition=='GoldenRatio'].saccade_length.mean()
# Out:
# 9.487588543833592
